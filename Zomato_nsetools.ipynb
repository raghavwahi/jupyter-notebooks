# %%
from nsetools import Nse

# %%
nse = Nse()

# %%
aa = nse.download_bhavcopy(str(date.date()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f1d77e94cf48> in <module>
# ----> 1 aa = nse.download_bhavcopy(str(date.date()))
#
# NameError: name 'date' is not defined

# %%
from io import StringIO
import pandas as pd

s = str(aa,'utf-8')

data = StringIO(s) 

df=pd.read_csv(data)

# %%
df[df.columns[:-1]]
# Out:
#           SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE      LAST  \
# 0     1018GS2026     GS     96.95     96.95     96.95     96.95     96.95
# 1      20MICRONS     EQ     62.90     64.50     62.30     62.70     62.90
# 2     21STCENMGM     EQ     49.10     51.10     49.10     51.10     51.10
# 3        3MINDIA     EQ  26282.00  26415.00  25825.00  26355.90  26250.00
# 4         3PLAND     EQ     13.90     14.10     13.55     13.75     13.75
# ...          ...    ...       ...       ...       ...       ...       ...
# 2167      ZOMATO     EQ    136.00    146.15    135.90    144.05    144.00
# 2168        ZOTA     EQ    405.15    415.00    395.10    399.55    399.00
# 2169       ZUARI     EQ    124.00    127.30    123.75    124.65    124.70
# 2170   ZUARIGLOB     EQ    139.90    139.90    135.00    135.50    135.50
# 2171   ZYDUSWELL     EQ   2314.90   2331.65   2281.00   2304.30   2307.00
#
#       PREVCLOSE  TOTTRDQTY     TOTTRDVAL    TIMESTAMP  TOTALTRADES  \
# ...

# %%
abc = nse.get_stock_codes()

# %%
hm = list(abc.keys())

# %%
import yfinance as yf

# %%
hm = [x + '.NS' for x in hm]

# %%
# df = pd.DataFrame()
# for item in stocks:
#     info = yf.Ticker(item)

# %%
tickers = yf.Tickers(','.join(hm))

# %%
import time
for item in hm[1:]:
    a = tickers.tickers[item].info
    print(a['shortName'])
    print('\n*10')
# Out:
# 20 MICRONS LTD
#
# *10
# 21ST CENTURY MANAG
#
# *10
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-33c7f5f63ccb> in <module>
#       2 for item in hm[1:]:
#       3     a = tickers.tickers[item].info
# ----> 4     print(a['shortName'])
#       5     print('\n*10')
#       6
#
# KeyError: 'shortName'

# %%
hm[5]
# Out:
# '3PLAND.NS'

# %%
ticker = yf.Tickers('3PLAND.NS')

# %%
ticker.tickers['3PLAND.NS'].info
# Out:
# {'exchange': 'NSI',
#  'shortName': '3P LAND HOLDINGS L',
#  'exchangeTimezoneName': 'Asia/Kolkata',
#  'exchangeTimezoneShortName': 'IST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '19800000',
#  'quoteType': 'EQUITY',
#  'symbol': '3PLAND.NS',
#  'market': 'in_market',
#  'previousClose': 13.1,
#  'regularMarketOpen': 13.7,
#  'twoHundredDayAverage': 13.60922,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': None,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 13.7,
#  'navPrice': None,
#  'averageDailyVolume10Day': 8616,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 13.1,
#  'fiftyDayAverage': 13.648529,
#  'trailingAnnualDividendRate': None,
#  'open': 13.7,
#  'toCurrency': None,
#  'averageVolume10days': 8616,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'beta': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 12.55,
# ...

# %%
a = {'zip': '400 703', 'sector': '', 'longBusinessSummary': '3i Infotech Limited provides IP based software solutions and information technology services in India and internationally. The company offers Kastle Universal Lending System, a centralized database and browser based application to integrate and streamline the loan processing cycle; Kastle Treasury, a treasury management solution; Kastle Core Banking that provides banking operations for commercial and consumer banking; Kastle Transaction Banking that enables cash and securities movement; Factor/SQL, a factoring software solution; Kastle Integrated Risk Management solution; AMLOCK, an anti-money laundering, and financial crime detection and management solution; Kastle Digital Banking solutions suite to cater the trends of banking and lending practices; and Kastle Business Intelligence, an enterprise analytics platform. It also provides general, life, and health insurance products under the PREMIA brands; PREMIA Blogs; PREMIA Pension; MFund Plus WMS, a wealth management platform technology solution; MFund Plus Suite, an investment/fund management solution; MFund Investor Services System; and PREMIA e-portal, an insurance-specific web portal solution. In addition, the company offers enterprise resource planning solutions, including ORION enterprise suite, a solution that provides industry-specific solutions; ORION financial management solution, which streamlines and unifies financial management process; ORION HRMS and payroll to enhance employee productivity and organizational efficiency; and ORION Mobile ERP, a mobile application to integrate various business processes and modules. Further, it provides customer relationship management and B2C solutions under ORION brand. It serves customers in banking, insurance, capital markets, asset and wealth management, government, manufacturing, retail, distribution, telecom, and healthcare industry verticals. The company was founded in 1993 and is headquartered in Navi Mumbai, India.', 'city': 'Navi Mumbai', 'phone': '91 22 7123 8000', 'country': 'India', 'companyOfficers': [], 'website': 'http://www.3i-infotech.com', 'maxAge': 1, 'address1': 'Tower # 5', 'fax': '91 22 6792 8098', 'industry': '', 'address2': '3rd to 6th Floors International Infotech Park Vashi', 'ebitdaMargins': -0.02217, 'profitMargins': 0.58158, 'grossMargins': 0.13246, 'operatingCashflow': None, 'revenueGrowth': -0.333, 'operatingMargins': -0.04911, 'ebitda': -142150000, 'targetLowPrice': None, 'recommendationKey': 'none', 'grossProfits': 787600000, 'freeCashflow': None, 'targetMedianPrice': None, 'currentPrice': 31, 'earningsGrowth': None, 'currentRatio': None, 'returnOnAssets': None, 'numberOfAnalystOpinions': None, 'targetMeanPrice': None, 'debtToEquity': 73.029, 'returnOnEquity': None, 'targetHighPrice': None, 'totalCash': 7621400064, 'totalDebt': 5498299904, 'totalRevenue': 6410100224, 'totalCashPerShare': 48.421, 'financialCurrency': 'INR', 'revenuePerShare': 39.803, 'quickRatio': None, 'recommendationMean': None, 'exchange': 'NSI', 'longName': '3i Infotech Limited', 'exchangeTimezoneName': 'Asia/Kolkata', 'exchangeTimezoneShortName': 'IST', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '19800000', 'quoteType': 'EQUITY', 'symbol': '3IINFOLTD.NS', 'messageBoardId': 'finmb_9376063', 'market': 'in_market', 'annualHoldingsTurnover': None, 'enterpriseToRevenue': 0.43, 'beta3Year': None, 'enterpriseToEbitda': -19.39, '52WeekChange': None, 'morningStarRiskRating': None, 'forwardEps': None, 'revenueQuarterlyGrowth': None, 'sharesOutstanding': None, 'fundInceptionDate': None, 'annualReportExpenseRatio': None, 'totalAssets': None, 'bookValue': 46.694, 'sharesShort': None, 'sharesPercentSharesOut': None, 'fundFamily': None, 'lastFiscalYearEnd': 1617148800, 'heldPercentInstitutions': 0.011089999, 'netIncomeToCommon': 2652800000, 'trailingEps': 23.148, 'lastDividendValue': None, 'SandP52WeekChange': 0.33635402, 'priceToBook': 0.66389686, 'heldPercentInsiders': 0.34235, 'nextFiscalYearEnd': 1680220800, 'yield': None, 'mostRecentQuarter': 1625011200, 'shortRatio': None, 'sharesShortPreviousMonthDate': None, 'floatShares': 132307292, 'beta': 1.70736, 'enterpriseValue': 2756300032, 'priceHint': 2, 'threeYearAverageReturn': None, 'lastSplitDate': None, 'lastSplitFactor': None, 'legalType': None, 'lastDividendDate': None, 'morningStarOverallRating': None, 'earningsQuarterlyGrowth': None, 'priceToSalesTrailing12Months': None, 'dateShortInterest': None, 'pegRatio': None, 'ytdReturn': None, 'forwardPE': None, 'lastCapGain': None, 'shortPercentOfFloat': None, 'sharesShortPriorMonth': None, 'impliedSharesOutstanding': None, 'category': None, 'fiveYearAverageReturn': None, 'previousClose': None, 'regularMarketOpen': None, 'twoHundredDayAverage': None, 'trailingAnnualDividendYield': None, 'payoutRatio': None, 'volume24Hr': None, 'regularMarketDayHigh': 31, 'navPrice': None, 'averageDailyVolume10Day': None, 'regularMarketPreviousClose': None, 'fiftyDayAverage': None, 'trailingAnnualDividendRate': None, 'open': None, 'toCurrency': None, 'averageVolume10days': None, 'expireDate': None, 'algorithm': None, 'dividendRate': None, 'exDividendDate': None, 'circulatingSupply': None, 'startDate': None, 'regularMarketDayLow': 29.55, 'currency': 'INR', 'trailingPE': 1.3392085, 'regularMarketVolume': 96188, 'lastMarket': None, 'maxSupply': None, 'openInterest': None, 'marketCap': None, 'volumeAllCurrencies': None, 'strikePrice': None, 'averageVolume': None, 'dayLow': 29.55, 'ask': None, 'askSize': None, 'volume': 96188, 'fiftyTwoWeekHigh': 31, 'fromCurrency': None, 'fiveYearAvgDividendYield': None, 'fiftyTwoWeekLow': 29.55, 'bid': 0, 'tradeable': False, 'dividendYield': None, 'bidSize': None, 'dayHigh': 31, 'regularMarketPrice': 31, 'logo_url': 'https://logo.clearbit.com/3i-infotech.com'}

# %%
b = {'err': None, 'exchange': 'NSI', 'shortName': '21ST CENTURY MANAG', 'longName': 'Twentyfirst Century Management Services Limited', 'exchangeTimezoneName': 'Asia/Kolkata', 'exchangeTimezoneShortName': 'IST', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '19800000', 'quoteType': 'EQUITY', 'symbol': '21STCENMGM.NS', 'messageBoardId': 'finmb_20406442', 'market': 'in_market', 'previousClose': 48.4, 'regularMarketOpen': 49.35, 'twoHundredDayAverage': 25.955, 'trailingAnnualDividendYield': None, 'payoutRatio': 0, 'volume24Hr': None, 'regularMarketDayHigh': 49.35, 'navPrice': None, 'averageDailyVolume10Day': 47061, 'totalAssets': None, 'regularMarketPreviousClose': 48.4, 'fiftyDayAverage': 45.69091, 'trailingAnnualDividendRate': None, 'open': 49.35, 'toCurrency': None, 'averageVolume10days': 47061, 'expireDate': None, 'yield': None, 'algorithm': None, 'dividendRate': None, 'exDividendDate': 1530662400, 'beta': 0.4513, 'circulatingSupply': None, 'startDate': None, 'regularMarketDayLow': 49.35, 'priceHint': 2, 'currency': 'INR', 'trailingPE': 1.1101613, 'regularMarketVolume': 28212, 'lastMarket': None, 'maxSupply': None, 'openInterest': None, 'marketCap': 523425824, 'volumeAllCurrencies': None, 'strikePrice': None, 'averageVolume': 14789, 'priceToSalesTrailing12Months': 0.18647899, 'dayLow': 49.35, 'ask': 0, 'ytdReturn': None, 'askSize': 0, 'volume': 28212, 'fiftyTwoWeekHigh': 55.25, 'forwardPE': None, 'maxAge': 1, 'fromCurrency': None, 'fiveYearAvgDividendYield': None, 'fiftyTwoWeekLow': 9.5, 'bid': 0, 'tradeable': False, 'dividendYield': None, 'bidSize': 0, 'dayHigh': 49.35, 'regularMarketPrice': 49.35, 'logo_url': ''}

# %%
c = {'zip': '391760', 'sector': 'Basic Materials', 'fullTimeEmployees': 329, 'longBusinessSummary': '20 Microns Limited engages in the industrial micronized minerals and specialty chemicals businesses in India. The company offers industrial minerals, such as ground calcium carbonate, dolomite, hydrous and calcined kaolins, talcs, natural barytes, silica/quartz, muscovite mica, feldspar/nepheline syenite, and natural and synthetic red oxide for applications in paints and coatings, inks and pigments, plastics and polymer, paper, rubber, cosmetics, ceramics, adhesive and sealant, oil-well drilling, agrochemicals, foundry, and other industries. It also provides functional additives and specialties, including white/buff and colored rutile TiO2, white pigment opacifiers, synthetic barium sulphate, micronized wax, anti-blocking additives, rheological additives, matting agents, inorganic thickeners, flame retardants, calcium oxide desiccant, activators for rubber, high aspect ratio talc, sub-micron CaCO3, decorative, and colored quartz sand; erueca mide, olea mide, and processing aids; and fumed, precipitated, and amorphous silica for applications in plastics and polymer, rubber, paints and coatings, inks and pigments, paper, cosmetics, foundry coating, and adhesive and sealant industries. The company also exports its products. 20 Microns Limited was founded in 1987 and is headquartered in Vadodara, India.', 'city': 'Vadodara', 'phone': '91 26 5232 1534', 'country': 'India', 'companyOfficers': [], 'website': 'http://www.20microns.com', 'maxAge': 1, 'address1': '347, GIDC Industrial Estate', 'industry': 'Other Industrial Metals & Mining', 'address2': 'Waghodia', 'ebitdaMargins': 0.12851, 'profitMargins': 0.04575, 'grossMargins': 0.47259998, 'operatingCashflow': 261494000, 'revenueGrowth': 0.267, 'operatingMargins': 0.109139994, 'ebitda': 733374016, 'targetLowPrice': 110, 'recommendationKey': 'buy', 'grossProfits': 2289282000, 'freeCashflow': -328490368, 'targetMedianPrice': 110, 'currentPrice': 58.4, 'earningsGrowth': -0.342, 'currentRatio': 1.356, 'returnOnAssets': 0.08838, 'numberOfAnalystOpinions': 1, 'targetMeanPrice': 110, 'debtToEquity': 52.643, 'returnOnEquity': 0.123509996, 'targetHighPrice': 110, 'totalCash': 123286000, 'totalDebt': 1190615040, 'totalRevenue': 5706521088, 'totalCashPerShare': 3.492, 'financialCurrency': 'INR', 'revenuePerShare': 161.783, 'quickRatio': 0.587, 'recommendationMean': 2, 'exchange': 'NSI', 'shortName': '20 MICRONS LTD', 'longName': '20 Microns Limited', 'exchangeTimezoneName': 'Asia/Kolkata', 'exchangeTimezoneShortName': 'IST', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '19800000', 'quoteType': 'EQUITY', 'symbol': '20MICRONS.NS', 'messageBoardId': 'finmb_137821', 'market': 'in_market', 'annualHoldingsTurnover': None, 'enterpriseToRevenue': 0.55, 'beta3Year': None, 'enterpriseToEbitda': 4.278, '52WeekChange': 1.1121156, 'morningStarRiskRating': None, 'forwardEps': None, 'revenueQuarterlyGrowth': None, 'sharesOutstanding': 35286500, 'fundInceptionDate': None, 'annualReportExpenseRatio': None, 'totalAssets': None, 'bookValue': 63.834, 'sharesShort': None, 'sharesPercentSharesOut': None, 'fundFamily': None, 'lastFiscalYearEnd': 1617148800, 'heldPercentInstitutions': 0, 'netIncomeToCommon': 261064992, 'trailingEps': 7.401, 'lastDividendValue': 0.6, 'SandP52WeekChange': 0.33635402, 'priceToBook': 0.914873, 'heldPercentInsiders': 0.60286, 'nextFiscalYearEnd': 1680220800, 'yield': None, 'mostRecentQuarter': 1632960000, 'shortRatio': None, 'sharesShortPreviousMonthDate': None, 'floatShares': 14512810, 'beta': None, 'enterpriseValue': 3137175296, 'priceHint': 2, 'threeYearAverageReturn': None, 'lastSplitDate': 1359331200, 'lastSplitFactor': '2:1', 'legalType': None, 'lastDividendDate': 1584576000, 'morningStarOverallRating': None, 'earningsQuarterlyGrowth': -0.228, 'priceToSalesTrailing12Months': 0.36111873, 'dateShortInterest': None, 'pegRatio': None, 'ytdReturn': None, 'forwardPE': None, 'lastCapGain': None, 'shortPercentOfFloat': None, 'sharesShortPriorMonth': None, 'impliedSharesOutstanding': None, 'category': None, 'fiveYearAverageReturn': None, 'previousClose': 59.55, 'regularMarketOpen': 59.75, 'twoHundredDayAverage': 56.576923, 'trailingAnnualDividendYield': 0, 'payoutRatio': 0, 'volume24Hr': None, 'regularMarketDayHigh': 62, 'navPrice': None, 'averageDailyVolume10Day': 221893, 'regularMarketPreviousClose': 59.55, 'fiftyDayAverage': 59.20714, 'trailingAnnualDividendRate': 0, 'open': 59.75, 'toCurrency': None, 'averageVolume10days': 221893, 'expireDate': None, 'algorithm': None, 'dividendRate': None, 'exDividendDate': 1584576000, 'circulatingSupply': None, 'startDate': None, 'regularMarketDayLow': 56.7, 'currency': 'INR', 'trailingPE': 7.8908257, 'regularMarketVolume': 227283, 'lastMarket': None, 'maxSupply': None, 'openInterest': None, 'marketCap': 2060731648, 'volumeAllCurrencies': None, 'strikePrice': None, 'averageVolume': 186905, 'dayLow': 56.7, 'ask': 0, 'askSize': 0, 'volume': 227283, 'fiftyTwoWeekHigh': 74.9, 'fromCurrency': None, 'fiveYearAvgDividendYield': None, 'fiftyTwoWeekLow': 26.05, 'bid': 0, 'tradeable': False, 'dividendYield': None, 'bidSize': 0, 'dayHigh': 62, 'regularMarketPrice': 58.4, 'logo_url': 'https://logo.clearbit.com/20microns.com'}

# %%
a['longName']
# Out:
# '3i Infotech Limited'

# %%
a = yf.Ticker('ZOMATO.NS')

# %%
a.balance_sheet
# Out:
#                              2021-03-31    2020-03-31    2019-03-31  \
# Intangible Assets          2.075470e+09  2.787910e+09  6.935400e+08
# Capital Surplus            1.285627e+11  4.816332e+10  4.435170e+10
# Total Liab                 6.105350e+09  2.197101e+10  8.449250e+09
# Total Stockholder Equity   7.643786e+10  4.573810e+09  2.356177e+10
# Minority Interest         -5.709000e+07 -6.500000e+07 -3.141700e+08
# Other Current Liab         1.790760e+09  4.183650e+09  2.908970e+09
# Total Assets               8.703543e+10  2.900382e+10  3.413405e+10
# Common Stock               3.500000e+05  3.400000e+05  3.400000e+05
# Other Current Assets       2.513010e+09  3.403260e+09  1.219040e+09
# Retained Earnings         -5.600306e+10 -4.666352e+10 -2.262481e+10
# Other Liab                 3.980800e+08  4.243900e+08  6.323400e+08
# Good Will                  1.247784e+10  1.209285e+10  1.884850e+09
# Treasury Stock             3.877880e+09  3.073670e+09  1.834540e+09
# ...

# %%
# Out:
# {'zip': '122009',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 3755,
#  'longBusinessSummary': 'Zomato Limited operates as an online food delivery company in India and internationally. Its technology platform connects customers, restaurant partners, and delivery partners. The company also operates Hyperpure, a procurement solution that supplies ingredients and kitchen products to restaurant partners. It offers restaurant search and discovery, online order, pick up, and table reservations services. Zomato Limited was founded in 2008 and is headquartered in Gurugram, India.',
#  'city': 'Gurugram',
#  'phone': '91 12 4426 8565',
#  'country': 'India',
#  'companyOfficers': [],
#  'website': 'http://www.zomato.com',
#  'maxAge': 1,
#  'address1': 'Ground Floor, Tower C',
#  'industry': 'Internet Retail',
#  'address2': 'Vipul Tech Square Sector 43 Golf Course Road',
#  'ebitdaMargins': -0.30233,
#  'profitMargins': -0.41568002,
#  'grossMargins': 0.52425,
# ...

# %%
ls = [a,b,c]

# %%
columns = []
for company_info in ls:
    if not len(columns):
        columns = list(company_info.keys())
    else:
        columns = list({*columns, *company_info.keys()})
        
        
    print('\n'*10)
    print(len(columns))
    print('\n')
    print('\n')
    print(columns)
# Out:
# 150
#
#
#
#
# ...

# %%
ls[0]
# Out:
# {'zip': '400 703',
#  'sector': '',
# ...

# %%
for item in ls:
    print(str(item['symbol']).split('.NS')[0])
# Out:
# 3IINFOLTD
# 21STCENMGM
# 20MICRONS
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-d97f93a2d258> in <module>
#       1 for item in ls:
# ----> 2     print(str(item['symbol']).split('.NS')[0])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
ls.append(None)

# %%
a = {'zip': '391760', 'sector': 'Basic Materials', 'fullTimeEmployees': 329, 'longBusinessSummary': '20 Microns Limited engages in the industrial micronized minerals and specialty chemicals businesses in India. The company offers industrial minerals, such as ground calcium carbonate, dolomite, hydrous and calcined kaolins, talcs, natural barytes, silica/quartz, muscovite mica, feldspar/nepheline syenite, and natural and synthetic red oxide for applications in paints and coatings, inks and pigments, plastics and polymer, paper, rubber, cosmetics, ceramics, adhesive and sealant, oil-well drilling, agrochemicals, foundry, and other industries. It also provides functional additives and specialties, including white/buff and colored rutile TiO2, white pigment opacifiers, synthetic barium sulphate, micronized wax, anti-blocking additives, rheological additives, matting agents, inorganic thickeners, flame retardants, calcium oxide desiccant, activators for rubber, high aspect ratio talc, sub-micron CaCO3, decorative, and colored quartz sand; erueca mide, olea mide, and processing aids; and fumed, precipitated, and amorphous silica for applications in plastics and polymer, rubber, paints and coatings, inks and pigments, paper, cosmetics, foundry coating, and adhesive and sealant industries. The company also exports its products. 20 Microns Limited was founded in 1987 and is headquartered in Vadodara, India.', 'city': 'Vadodara', 'phone': '91 26 5232 1534', 'country': 'India', 'companyOfficers': [], 'website': 'http://www.20microns.com', 'maxAge': 1, 'address1': '347, GIDC Industrial Estate', 'industry': 'Other Industrial Metals & Mining', 'address2': 'Waghodia', 'ebitdaMargins': 0.12851, 'profitMargins': 0.04575, 'grossMargins': 0.47259998, 'operatingCashflow': 261494000, 'revenueGrowth': 0.267, 'operatingMargins': 0.109139994, 'ebitda': 733374016, 'targetLowPrice': 110, 'recommendationKey': 'buy', 'grossProfits': 2289282000, 'freeCashflow': -328490368, 'targetMedianPrice': 110, 'currentPrice': 58.3, 'earningsGrowth': -0.342, 'currentRatio': 1.356, 'returnOnAssets': 0.08838, 'numberOfAnalystOpinions': 1, 'targetMeanPrice': 110, 'debtToEquity': 52.643, 'returnOnEquity': 0.123509996, 'targetHighPrice': 110, 'totalCash': 123286000, 'totalDebt': 1190615040, 'totalRevenue': 5706521088, 'totalCashPerShare': 3.492, 'financialCurrency': 'INR', 'revenuePerShare': 161.783, 'quickRatio': 0.587, 'recommendationMean': 2, 'exchange': 'NSI', 'shortName': '20 MICRONS LTD', 'longName': '20 Microns Limited', 'exchangeTimezoneName': 'Asia/Kolkata', 'exchangeTimezoneShortName': 'IST', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '19800000', 'quoteType': 'EQUITY', 'symbol': '20MICRONS', 'messageBoardId': 'finmb_137821', 'market': 'in_market', 'annualHoldingsTurnover': None, 'enterpriseToRevenue': 0.55, 'beta3Year': None, 'enterpriseToEbitda': 4.278, '52WeekChange': 1.1121156, 'morningStarRiskRating': None, 'forwardEps': None, 'revenueQuarterlyGrowth': None, 'sharesOutstanding': 35286500, 'fundInceptionDate': None, 'annualReportExpenseRatio': None, 'totalAssets': None, 'bookValue': 63.834, 'sharesShort': None, 'sharesPercentSharesOut': None, 'fundFamily': None, 'lastFiscalYearEnd': 1617148800, 'heldPercentInstitutions': 0, 'netIncomeToCommon': 261064992, 'trailingEps': 7.401, 'lastDividendValue': 0.6, 'SandP52WeekChange': 0.33635402, 'priceToBook': 0.91330636, 'heldPercentInsiders': 0.60286, 'nextFiscalYearEnd': 1680220800, 'yield': None, 'mostRecentQuarter': 1632960000, 'shortRatio': None, 'sharesShortPreviousMonthDate': None, 'floatShares': 14512810, 'beta': None, 'enterpriseValue': 3137175296, 'priceHint': 2, 'threeYearAverageReturn': None, 'lastSplitDate': 1359331200, 'lastSplitFactor': '2:1', 'legalType': None, 'lastDividendDate': 1584576000, 'morningStarOverallRating': None, 'earningsQuarterlyGrowth': -0.228, 'priceToSalesTrailing12Months': 0.36050037, 'dateShortInterest': None, 'pegRatio': None, 'ytdReturn': None, 'forwardPE': None, 'lastCapGain': None, 'shortPercentOfFloat': None, 'sharesShortPriorMonth': None, 'impliedSharesOutstanding': None, 'category': None, 'fiveYearAverageReturn': None, 'previousClose': 59.55, 'regularMarketOpen': 59.75, 'twoHundredDayAverage': 56.576923, 'trailingAnnualDividendYield': 0, 'payoutRatio': 0, 'volume24Hr': None, 'regularMarketDayHigh': 62, 'navPrice': None, 'averageDailyVolume10Day': 221893, 'regularMarketPreviousClose': 59.55, 'fiftyDayAverage': 59.20714, 'trailingAnnualDividendRate': 0, 'open': 59.75, 'toCurrency': None, 'averageVolume10days': 221893, 'expireDate': None, 'algorithm': None, 'dividendRate': None, 'exDividendDate': 1584576000, 'circulatingSupply': None, 'startDate': None, 'regularMarketDayLow': 56.7, 'currency': 'INR', 'trailingPE': 7.8773136, 'regularMarketVolume': 234159, 'lastMarket': None, 'maxSupply': None, 'openInterest': None, 'marketCap': 2057202944, 'volumeAllCurrencies': None, 'strikePrice': None, 'averageVolume': 186905, 'dayLow': 56.7, 'ask': 0, 'askSize': 0, 'volume': 234159, 'fiftyTwoWeekHigh': 74.9, 'fromCurrency': None, 'fiveYearAvgDividendYield': None, 'fiftyTwoWeekLow': 26.05, 'bid': 0, 'tradeable': False, 'dividendYield': None, 'bidSize': 0, 'dayHigh': 62, 'regularMarketPrice': 58.3, 'logo_url': 'https://logo.clearbit.com/20microns.com', 'fax': None}

# %%
import pandas as pd
df = pd.DataFrame(a, index=[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-ad5a5eb9a8bc> in <module>
#       1 import pandas as pd
# ----> 2 df = pd.DataFrame(a, index=[0])
#
# c:\users\ragha\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# c:\users\ragha\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
d = {}
for index, item in enumerate(ls):
    d[index] = item

# %%
# main = pd.DataFrame()
for index,item in enumerate(ls):
    print(index)
    df = pd.DataFrame(item, index=[index])
    main = main.append(df)
# Out:
# 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-c2a5a58d4182> in <module>
#       2 for index,item in enumerate(ls):
#       3     print(index)
# ----> 4     df = pd.DataFrame(item, index=[index])
#       5     main = main.append(df)
#
# c:\users\ragha\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ...

# %%
main
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
ls[0]
# Out:
# {'zip': '400 703',
#  'sector': '',
# ...

# %%
ls[1]
# Out:
# {'err': None,
#  'exchange': 'NSI',
#  'shortName': '21ST CENTURY MANAG',
#  'longName': 'Twentyfirst Century Management Services Limited',
#  'exchangeTimezoneName': 'Asia/Kolkata',
#  'exchangeTimezoneShortName': 'IST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '19800000',
#  'quoteType': 'EQUITY',
#  'symbol': '21STCENMGM.NS',
#  'messageBoardId': 'finmb_20406442',
#  'market': 'in_market',
#  'previousClose': 48.4,
#  'regularMarketOpen': 49.35,
#  'twoHundredDayAverage': 25.955,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': 0,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 49.35,
#  'navPrice': None,
#  'averageDailyVolume10Day': 47061,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 48.4,
#  'fiftyDayAverage': 45.69091,
#  'trailingAnnualDividendRate': None,
#  'open': 49.35,
#  'toCurrency': None,
#  'averageVolume10days': 47061,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': None,
# ...

# %%
pd.DataFrame({'zip': '391760', 'sector': 'Basic Materials', 'fullTimeEmployees': 329, 'longBusinessSummary': '20 Microns Limited engages in the industrial micronized minerals and specialty chemicals businesses in India. The company offers industrial minerals, such as ground calcium carbonate, dolomite, hydrous and calcined kaolins, talcs, natural barytes, silica/quartz, muscovite mica, feldspar/nepheline syenite, and natural and synthetic red oxide for applications in paints and coatings, inks and pigments, plastics and polymer, paper, rubber, cosmetics, ceramics, adhesive and sealant, oil-well drilling, agrochemicals, foundry, and other industries. It also provides functional additives and specialties, including white/buff and colored rutile TiO2, white pigment opacifiers, synthetic barium sulphate, micronized wax, anti-blocking additives, rheological additives, matting agents, inorganic thickeners, flame retardants, calcium oxide desiccant, activators for rubber, high aspect ratio talc, sub-micron CaCO3, decorative, and colored quartz sand; erueca mide, olea mide, and processing aids; and fumed, precipitated, and amorphous silica for applications in plastics and polymer, rubber, paints and coatings, inks and pigments, paper, cosmetics, foundry coating, and adhesive and sealant industries. The company also exports its products. 20 Microns Limited was founded in 1987 and is headquartered in Vadodara, India.', 'city': 'Vadodara', 'phone': '91 26 5232 1534', 'country': 'India', 'companyOfficers': [], 'website': 'http://www.20microns.com', 'maxAge': 1, 'address1': '347, GIDC Industrial Estate', 'industry': 'Other Industrial Metals & Mining', 'address2': 'Waghodia', 'ebitdaMargins': 0.12851, 'profitMargins': 0.04575, 'grossMargins': 0.47259998, 'operatingCashflow': 261494000, 'revenueGrowth': 0.267, 'operatingMargins': 0.109139994, 'ebitda': 733374016, 'targetLowPrice': 110, 'recommendationKey': 'buy', 'grossProfits': 2289282000, 'freeCashflow': -328490368, 'targetMedianPrice': 110, 'currentPrice': 58.3, 'earningsGrowth': -0.342, 'currentRatio': 1.356, 'returnOnAssets': 0.08838, 'numberOfAnalystOpinions': 1, 'targetMeanPrice': 110, 'debtToEquity': 52.643, 'returnOnEquity': 0.123509996, 'targetHighPrice': 110, 'totalCash': 123286000, 'totalDebt': 1190615040, 'totalRevenue': 5706521088, 'totalCashPerShare': 3.492, 'financialCurrency': 'INR', 'revenuePerShare': 161.783, 'quickRatio': 0.587, 'recommendationMean': 2, 'exchange': 'NSI', 'shortName': '20 MICRONS LTD', 'longName': '20 Microns Limited', 'exchangeTimezoneName': 'Asia/Kolkata', 'exchangeTimezoneShortName': 'IST', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '19800000', 'quoteType': 'EQUITY', 'symbol': '20MICRONS', 'messageBoardId': 'finmb_137821', 'market': 'in_market', 'annualHoldingsTurnover': None, 'enterpriseToRevenue': 0.55, 'beta3Year': None, 'enterpriseToEbitda': 4.278, '52WeekChange': 1.1121156, 'morningStarRiskRating': None, 'forwardEps': None, 'revenueQuarterlyGrowth': None, 'sharesOutstanding': 35286500, 'fundInceptionDate': None, 'annualReportExpenseRatio': None, 'totalAssets': None, 'bookValue': 63.834, 'sharesShort': None, 'sharesPercentSharesOut': None, 'fundFamily': None, 'lastFiscalYearEnd': 1617148800, 'heldPercentInstitutions': 0, 'netIncomeToCommon': 261064992, 'trailingEps': 7.401, 'lastDividendValue': 0.6, 'SandP52WeekChange': 0.33635402, 'priceToBook': 0.91330636, 'heldPercentInsiders': 0.60286, 'nextFiscalYearEnd': 1680220800, 'yield': None, 'mostRecentQuarter': 1632960000, 'shortRatio': None, 'sharesShortPreviousMonthDate': None, 'floatShares': 14512810, 'beta': None, 'enterpriseValue': 3137175296, 'priceHint': 2, 'threeYearAverageReturn': None, 'lastSplitDate': 1359331200, 'lastSplitFactor': '2:1', 'legalType': None, 'lastDividendDate': 1584576000, 'morningStarOverallRating': None, 'earningsQuarterlyGrowth': -0.228, 'priceToSalesTrailing12Months': 0.36050037, 'dateShortInterest': None, 'pegRatio': None, 'ytdReturn': None, 'forwardPE': None, 'lastCapGain': None, 'shortPercentOfFloat': None, 'sharesShortPriorMonth': None, 'impliedSharesOutstanding': None, 'category': None, 'fiveYearAverageReturn': None, 'previousClose': 59.55, 'regularMarketOpen': 59.75, 'twoHundredDayAverage': 56.576923, 'trailingAnnualDividendYield': 0, 'payoutRatio': 0, 'volume24Hr': None, 'regularMarketDayHigh': 62, 'navPrice': None, 'averageDailyVolume10Day': 221893, 'regularMarketPreviousClose': 59.55, 'fiftyDayAverage': 59.20714, 'trailingAnnualDividendRate': 0, 'open': 59.75, 'toCurrency': None, 'averageVolume10days': 221893, 'expireDate': None, 'algorithm': None, 'dividendRate': None, 'exDividendDate': 1584576000, 'circulatingSupply': None, 'startDate': None, 'regularMarketDayLow': 56.7, 'currency': 'INR', 'trailingPE': 7.8773136, 'regularMarketVolume': 234159, 'lastMarket': None, 'maxSupply': None, 'openInterest': None, 'marketCap': 2057202944, 'volumeAllCurrencies': None, 'strikePrice': None, 'averageVolume': 186905, 'dayLow': 56.7, 'ask': 0, 'askSize': 0, 'volume': 234159, 'fiftyTwoWeekHigh': 74.9, 'fromCurrency': None, 'fiveYearAvgDividendYield': None, 'fiftyTwoWeekLow': 26.05, 'bid': 0, 'tradeable': False, 'dividendYield': None, 'bidSize': 0, 'dayHigh': 62, 'regularMarketPrice': 58.3, 'logo_url': 'https://logo.clearbit.com/20microns.com', 'fax': None})
# Out:
# Empty DataFrame
# ...

# %%
bb = {'zip': '391760', 'sector': 'Basic Materials', 'fullTimeEmployees': 329, 'longBusinessSummary': '20 Microns Limited engages in the industrial micronized minerals and specialty chemicals businesses in India. The company offers industrial minerals, such as ground calcium carbonate, dolomite, hydrous and calcined kaolins, talcs, natural barytes, silica/quartz, muscovite mica, feldspar/nepheline syenite, and natural and synthetic red oxide for applications in paints and coatings, inks and pigments, plastics and polymer, paper, rubber, cosmetics, ceramics, adhesive and sealant, oil-well drilling, agrochemicals, foundry, and other industries. It also provides functional additives and specialties, including white/buff and colored rutile TiO2, white pigment opacifiers, synthetic barium sulphate, micronized wax, anti-blocking additives, rheological additives, matting agents, inorganic thickeners, flame retardants, calcium oxide desiccant, activators for rubber, high aspect ratio talc, sub-micron CaCO3, decorative, and colored quartz sand; erueca mide, olea mide, and processing aids; and fumed, precipitated, and amorphous silica for applications in plastics and polymer, rubber, paints and coatings, inks and pigments, paper, cosmetics, foundry coating, and adhesive and sealant industries. The company also exports its products. 20 Microns Limited was founded in 1987 and is headquartered in Vadodara, India.', 'city': 'Vadodara', 'phone': '91 26 5232 1534', 'country': 'India', 'companyOfficers': [], 'website': 'http://www.20microns.com', 'maxAge': 1, 'address1': '347, GIDC Industrial Estate', 'industry': 'Other Industrial Metals & Mining', 'address2': 'Waghodia', 'ebitdaMargins': 0.12851, 'profitMargins': 0.04575, 'grossMargins': 0.47259998, 'operatingCashflow': 261494000, 'revenueGrowth': 0.267, 'operatingMargins': 0.109139994, 'ebitda': 733374016, 'targetLowPrice': 110, 'recommendationKey': 'buy', 'grossProfits': 2289282000, 'freeCashflow': -328490368, 'targetMedianPrice': 110, 'currentPrice': 58.3, 'earningsGrowth': -0.342, 'currentRatio': 1.356, 'returnOnAssets': 0.08838, 'numberOfAnalystOpinions': 1, 'targetMeanPrice': 110, 'debtToEquity': 52.643, 'returnOnEquity': 0.123509996, 'targetHighPrice': 110, 'totalCash': 123286000, 'totalDebt': 1190615040, 'totalRevenue': 5706521088, 'totalCashPerShare': 3.492, 'financialCurrency': 'INR', 'revenuePerShare': 161.783, 'quickRatio': 0.587, 'recommendationMean': 2, 'exchange': 'NSI', 'shortName': '20 MICRONS LTD', 'longName': '20 Microns Limited', 'exchangeTimezoneName': 'Asia/Kolkata', 'exchangeTimezoneShortName': 'IST', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '19800000', 'quoteType': 'EQUITY', 'symbol': '20MICRONS', 'messageBoardId': 'finmb_137821', 'market': 'in_market', 'annualHoldingsTurnover': None, 'enterpriseToRevenue': 0.55, 'beta3Year': None, 'enterpriseToEbitda': 4.278, '52WeekChange': 1.1121156, 'morningStarRiskRating': None, 'forwardEps': None, 'revenueQuarterlyGrowth': None, 'sharesOutstanding': 35286500, 'fundInceptionDate': None, 'annualReportExpenseRatio': None, 'totalAssets': None, 'bookValue': 63.834, 'sharesShort': None, 'sharesPercentSharesOut': None, 'fundFamily': None, 'lastFiscalYearEnd': 1617148800, 'heldPercentInstitutions': 0, 'netIncomeToCommon': 261064992, 'trailingEps': 7.401, 'lastDividendValue': 0.6, 'SandP52WeekChange': 0.33635402, 'priceToBook': 0.91330636, 'heldPercentInsiders': 0.60286, 'nextFiscalYearEnd': 1680220800, 'yield': None, 'mostRecentQuarter': 1632960000, 'shortRatio': None, 'sharesShortPreviousMonthDate': None, 'floatShares': 14512810, 'beta': None, 'enterpriseValue': 3137175296, 'priceHint': 2, 'threeYearAverageReturn': None, 'lastSplitDate': 1359331200, 'lastSplitFactor': '2:1', 'legalType': None, 'lastDividendDate': 1584576000, 'morningStarOverallRating': None, 'earningsQuarterlyGrowth': -0.228, 'priceToSalesTrailing12Months': 0.36050037, 'dateShortInterest': None, 'pegRatio': None, 'ytdReturn': None, 'forwardPE': None, 'lastCapGain': None, 'shortPercentOfFloat': None, 'sharesShortPriorMonth': None, 'impliedSharesOutstanding': None, 'category': None, 'fiveYearAverageReturn': None, 'previousClose': 59.55, 'regularMarketOpen': 59.75, 'twoHundredDayAverage': 56.576923, 'trailingAnnualDividendYield': 0, 'payoutRatio': 0, 'volume24Hr': None, 'regularMarketDayHigh': 62, 'navPrice': None, 'averageDailyVolume10Day': 221893, 'regularMarketPreviousClose': 59.55, 'fiftyDayAverage': 59.20714, 'trailingAnnualDividendRate': 0, 'open': 59.75, 'toCurrency': None, 'averageVolume10days': 221893, 'expireDate': None, 'algorithm': None, 'dividendRate': None, 'exDividendDate': 1584576000, 'circulatingSupply': None, 'startDate': None, 'regularMarketDayLow': 56.7, 'currency': 'INR', 'trailingPE': 7.8773136, 'regularMarketVolume': 234159, 'lastMarket': None, 'maxSupply': None, 'openInterest': None, 'marketCap': 2057202944, 'volumeAllCurrencies': None, 'strikePrice': None, 'averageVolume': 186905, 'dayLow': 56.7, 'ask': 0, 'askSize': 0, 'volume': 234159, 'fiftyTwoWeekHigh': 74.9, 'fromCurrency': None, 'fiveYearAvgDividendYield': None, 'fiftyTwoWeekLow': 26.05, 'bid': 0, 'tradeable': False, 'dividendYield': None, 'bidSize': 0, 'dayHigh': 62, 'regularMarketPrice': 58.3, 'logo_url': 'https://logo.clearbit.com/20microns.com', 'fax': None}

# %%
import numpy as np
for key, value in bb.items():
    if not value:
        bb[key] = np.nan

# %%
pd.DataFrame(bb, index=[0])
# Out:
#       zip           sector  fullTimeEmployees  \
# 0  391760  Basic Materials                329
#
#                                  longBusinessSummary      city  \
# 0  20 Microns Limited engages in the industrial m...  Vadodara
#
#              phone country  companyOfficers                   website  maxAge  \
# 0  91 26 5232 1534   India              NaN  http://www.20microns.com       1
#
#    ... fiveYearAvgDividendYield fiftyTwoWeekLow bid  tradeable  dividendYield  \
# 0  ...                      NaN           26.05 NaN        NaN            NaN
#
#    bidSize  dayHigh  regularMarketPrice  \
# 0      NaN       62                58.3
#
#                                   logo_url  fax
# 0  https://logo.clearbit.com/20microns.com  NaN
#
# [1 rows x 152 columns]
